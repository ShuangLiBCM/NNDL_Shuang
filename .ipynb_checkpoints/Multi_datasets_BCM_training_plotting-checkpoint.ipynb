# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from time import time
import seaborn as sns
import pandas as pd
import BCM
import data_loader
% matplotlib inline

# %%
w = np.array([[1,0],[0,1]])
w

plt.plot([0,w[0][0]],[0,w[0][1]])
plt.plot([0,w[1][0]],[0,w[1][1]])

# %%
# Load laplace data
Laplace_rt_wt,Laplace_w = data_loader.load_laplace(loc = 0, scale = 1, sample_size = 1000,dimension = 2,skew = False, whiten = True, rotation = False)

# %%
# Train BCM model with Laplace data

ny = 2    # 2 output neurons

p = 2
eta = 0.0005
tau = 200
batch = 1

# nonlinear = 'Relu'
# obj_type = 'QBCM'
# n_epoch = 40
# decay = 0.5

# nonlinear = 'Sigmoid'
# obj_type = 'QBCM'
# n_epoch = 200
# decay = 0.005


nonlinear = 'Relu'
obj_type = 'Kurtosis'
eta = 0.00005
n_epoch = 200
decay = 0.005


BCM_laplace = BCM.bcm_train(Laplace_rt_wt,eta = 0.0001, n_epoch = 10, batch = 1, ny = 2,tau = 200, thres = 0, p = 2,random_state = None, shuffle = True, nonlinear = nonlinear, obj_type = obj_type,decay = 0.0)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-217-4869d942e44e> in <module>()
#      25 decay = 0.005
#      26
# ---> 27 BCM_Iris = BCM.bcm_train(s_rt_wt,eta = 0.0001, n_epoch = 10, batch = 1, ny = 2,tau = 200, thres = 0, p = 2,random_state = None, shuffle = True, nonlinear = nonlinear, obj_type = obj_type,decay = 0.0)
#
# /notebooks/NNDL_Shuang/BCM.py in bcm_train(s_rt_wt, eta, n_epoch, batch, ny, tau, thres, p, random_state, shuffle, nonlinear, obj_type, decay)
#     172     t0 = time()
#     173     # Train teh model with data s_rt_wt
# --> 174     BCM_data.fit(s_rt_wt)
#     175     print("done in %0.3fs" % (time()-t0))
#     176
#
# /notebooks/NNDL_Shuang/BCM.py in fit(self, X)
#      84                             self.w_[:,j] = self.w_[:,j]/np.sqrt(np.sum((self.w_[:,j])**2))     # L2 norm of kurtosis learnin rule
#      85                     threshold[j] = self._ema(x = threshold[j],y = y[j],power = self.p)
# ---> 86                     bcm_obj[j] = obj(X,w = self.w_[:,j],obj_type = self.obj_type,nonlinear = self.nonlinear)
#      87                 w_tmp = np.concatenate(self.w_.T, axis=0)    # make 2*2 matrix into 1*4, preparing for weight tracking
#      88                 self.y_thres.append(y)
#
# /notebooks/NNDL_Shuang/BCM.py in obj(X, w, obj_type, nonlinear)
#     138         obj = np.divide(obj1,obj2**1.5)
#     139
# --> 140     return obj
#     141
#     142 # Perform zca whitening
#
# UnboundLocalError: local variable 'obj' referenced before assignment

# %%
# %debug
# Out:
# > /notebooks/NNDL_Shuang/BCM.py(140)obj()
#     138         obj = np.divide(obj1,obj2**1.5)
#     139
# --> 140     return obj
#     141
#     142 # Perform zca whitening
#
# ipdb> up
# > /notebooks/NNDL_Shuang/BCM.py(86)fit()
#      84                             self.w_[:,j] = self.w_[:,j]/np.sqrt(np.sum((self.w_[:,j])**2))     # L2 norm of kurtosis learnin rule
#      85                     threshold[j] = self._ema(x = threshold[j],y = y[j],power = self.p)
# ---> 86                     bcm_obj[j] = obj(X,w = self.w_[:,j],obj_type = self.obj_type,nonlinear = self.nonlinear)
#      87                 w_tmp = np.concatenate(self.w_.T, axis=0)    # make 2*2 matrix into 1*4, preparing for weight tracking
#      88                 self.y_thres.append(y)
#
# ipdb> obj?
# *** SyntaxError: invalid syntax

# %%
# Contruct objective function and 2D contour 
# Track the weight update trajectory
# Plot the trained weights on top
# Generate the objective function landscape

w_min = -7
w_max = 7
reso = 50

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
decay = 0.05

para = [ny,n_epoch,p,eta,tau,batch,decay]

BCM.bcm_obj(Laplace_rt_wt,w_min,w_max,reso,para,ori_w = Laplace_w )

# %%
# Load Iris data
Iris_rt_wt = data_loader.load_Iris()

# %%
# plot the objective function and training trajectory with Iris data

w_min = -7
w_max = 7
reso = 50

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
decay = 0

para = [ny,n_epoch,p,eta,tau,batch,decay]

BCM.bcm_obj(Iris_rt_wt,w_min,w_max,reso,para)

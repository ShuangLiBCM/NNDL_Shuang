# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from time import time
import seaborn as sns
import pandas as pd
import BCM
import data_loader
% matplotlib inline

# %%
# Load laplace data
Laplace_rt_wt = data_loader.load_laplace(loc = 0, scale = 1, sample_size = 1000,dimension = 2,skew = False, whiten = True, rotation = True)

# %%
# Train BCM model with Laplace data

ny = 2    # 2 output neurons

p = 2
eta = 0.0005
tau = 200
batch = 1

nonlinear = 'Relu'
obj_type = 'QBCM'
n_epoch = 40
decay = 0.5

nonlinear = 'Sigmoid'
obj_type = 'QBCM'
n_epoch = 200
decay = 0.05

BCM_Iris = BCM.bcm_train(Laplace_rt_wt,eta = eta,n_epoch = n_epoch,batch = batch,ny = ny,tau = tau, thres = 0, p = p,random_state = None, shuffle = True,decay = decay)
# Out:
# done in 5.017s

# %%
# Contruct objective function and 2D contour 
# Track the weight update trajectory
# Plot the trained weights on top
# Generate the objective function landscape

w_min = -7
w_max = 7
reso = 50

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
decay = 0

para = [ny,n_epoch,p,eta,tau,batch,decay]

BCM.bcm_obj(Laplace_rt_wt,w_min,w_max,reso,para)

# %%
# Load Iris data
Iris_rt_wt = data_loader.load_Iris()

# %%
# plot the objective function and training trajectory with Iris data

w_min = -7
w_max = 7
reso = 50

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
decay = 0.005

para = [ny,n_epoch,p,eta,tau,batch,decay]

BCM.bcm_obj(Iris_rt_wt,w_min,w_max,reso,para)

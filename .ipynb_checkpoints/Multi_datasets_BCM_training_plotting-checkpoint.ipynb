# %% [markdown]
# In this notebook,our goal is to study the BCM related objective function and local learning rule on various datasets.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from time import time
import seaborn as sns
import pandas as pd
import BCM
import data_loader
% matplotlib inline

# %%
# Load laplace data with 45 degree rotation
Laplace_rt_wt,Laplace_w = data_loader.load_laplace(loc = 0, scale = 1, sample_size = 1000,dimension = 2,skew = False, whiten = True, rotation = True)

# %%
# Check orignal dimension
print(Laplace_w)
plt.figure()
w_tmp = Laplace_w
w_tmp = w_tmp * 5
plt.plot([0,w_tmp[0][0]],[0,w_tmp[0][1]])
plt.plot([0,w_tmp[1][0]],[0,w_tmp[1][1]])
plt.plot(Laplace_rt_wt[:,0],Laplace_rt_wt[:,1],'.k', ms=4)
# Out:
# [[-0.87065816 -0.25552118]
#  [-0.68540387  0.82745677]]

# %%
# Train BCM model with Laplace data

ny = 2    # 2 output neurons

p = 2
tau = 200
batch = 1

# nonlinear = 'Relu'
# obj_type = 'QBCM'
# n_epoch = 40
# decay = 0.5

nonlinear = 'Sigmoid'
obj_type = 'QBCM'
n_epoch = 200
decay = 0.005
eta = 0.005


# nonlinear = 'Relu'
# obj_type = 'kurtosis'
# eta = 0.00005
# n_epoch = 40
# decay = 0.005


BCM_laplace = BCM.bcm_train(Laplace_rt_wt,eta = eta, n_epoch = n_epoch, batch = batch , ny = ny,tau = tau, thres = 0, p = p,random_state = None, shuffle = True, nonlinear = nonlinear, obj_type = obj_type,decay = decay = 0.005)
# Out:
# done in 74.025s

# %%
# Contruct objective function and 2D contour 
# Track the weight update trajectory
# Plot the trained weights on top
# Generate the objective function landscape

w_min = -7
w_max = 7
reso = 50

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
decay = 0.05

para = [ny,n_epoch,p,eta,tau,batch,decay]

BCM.bcm_obj(Laplace_rt_wt,w_min,w_max,reso,para,ori_w = Laplace_w)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-81512b823e5d> in <module>()
#      18 para = [ny,n_epoch,p,eta,tau,batch,decay]
#      19
# ---> 20 BCM.bcm_obj(Laplace_rt_wt,w_min,w_max,reso,para,ori_w = Laplace_w)
#
# /notebooks/NNDL_Shuang/BCM.py in bcm_obj(s_rt_wt, w_min, w_max, reso, para, ori_w)
#     290
#     291             BCM_data = bcm(eta = eta,n_epoch = n_epoch,batch = batch,ny = ny,tau = tau, thres = 0, p = p,random_state = None, shuffle = True, nonlinear = nonlinear, obj_type = obj_type,decay = decay)
# --> 292             BCM_data.fit(s_rt_wt)
#     293             BCM_data_w = np.vstack(BCM_data.w_track)
#     294
#
# /notebooks/NNDL_Shuang/BCM.py in fit(self, X)
#      91
#      92                     threshold[j] = self._ema(x = threshold[j],y = y[j],power = self.p)
# ---> 93                     bcm_obj[j] = obj(X,w = self.w_[:,j],obj_type = self.obj_type,nonlinear = self.nonlinear)
#      94                 w_tmp = np.concatenate(self.w_.T, axis=0)    # make 2*2 matrix into 1*4, preparing for weight tracking
#      95                 self.y_thres.append(y)
#
# /notebooks/NNDL_Shuang/BCM.py in obj(X, w, obj_type, nonlinear)
#     139         obj = obj1/3 - obj2**2/4
#     140     elif obj_type == 'kurtosis':
# --> 141         obj1 = (c**4).mean(axis = 0)
#     142         obj2 = (c**2).mean(axis = 0)
#     143         obj = obj1 - obj2**2*3
#
# KeyboardInterrupt:

# %%
# Load laplace data
Laplace_rt_wt,Laplace_w = data_loader.load_laplace(loc = 0, scale = 1, sample_size = 1000,dimension = 2,skew = False, whiten = True, rotation = False)

# %%
# Load Iris data
Iris_rt_wt = data_loader.load_Iris()

# %%
# plot the objective function and training trajectory with Iris data

w_min = -7
w_max = 7
reso = 50

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
decay = 0

para = [ny,n_epoch,p,eta,tau,batch,decay]

BCM.bcm_obj(Iris_rt_wt,w_min,w_max,reso,para)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from time import time
import seaborn as sns
import pandas as pd
import BCM
import data_loader
% matplotlib inline

# %%
#s_rt_wt = data_loader.load_Iris()
s_rt_wt = data_loader.load_laplace()

# %%
# Train BCM model with Laplace data

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
nonlinear = None
obj_type = 'QBCM'

BCM_Iris = BCM.bcm_train(s_rt_wt,eta = eta,n_epoch = n_epoch,batch = batch,ny = ny,tau = tau, thres = 0, p = p,random_state = None, shuffle = True)
# Out:
# done in 4.564s

# %%
# Contruct objective function and 2D contour 
# Track the weight update trajectory
# Plot the trained weights on top
# Generate the objective function landscape

w_min = -7
w_max = 7
reso = 50

ny = 2    # 2 output neurons
n_epoch = 200
p = 2
eta = 0.0005
tau = 200
batch = 1
para = [ny,n_epoch,p,eta,tau,batch]

BCM.bcm_obj(s_rt_wt,w_min,w_max,reso,para)
